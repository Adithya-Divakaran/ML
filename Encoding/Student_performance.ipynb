# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/Encoding/StudentsPerformance.csv")
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['gender_enc'] = le.fit_transform(df['gender'])
df['lunch_enc'] = le.fit_transform(df['lunch'])
df['test_prep_enc'] = le.fit_transform(df['test preparation course'])

# %%
df[['gender', 'gender_enc','lunch','lunch_enc','test preparation course','test_prep_enc']].head()
# Out:
#    gender  gender_enc         lunch  lunch_enc test preparation course  \
# 0  female           0      standard          1                    none
# 1  female           0      standard          1               completed
# 2  female           0      standard          1                    none
# 3    male           1  free/reduced          0                    none
# 4    male           1      standard          1                    none
#
#    test_prep_enc
# 0              1
# 1              0
# 2              1
# 3              1
# 4              1

# %%
from sklearn.preprocessing import OrdinalEncoder

education_order = [
    'some high school',
    'high school',
    'some college',
    "associate's degree",
    "bachelor's degree",
    "master's degree"
]

ord_enc = OrdinalEncoder(categories=[education_order])

df['parent_edu_enc'] = ord_enc.fit_transform(
    df[['parental level of education']]
)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    gender_enc  lunch_enc  test_prep_enc  parent_edu_enc
# 0           0          1              1             4.0
# ...

# %%
df[['parental level of education','parent_edu_enc']].head()
# Out:
#   parental level of education  parent_edu_enc
# 0           bachelor's degree             4.0
# 1                some college             2.0
# 2             master's degree             5.0
# 3          associate's degree             3.0
# 4                some college             2.0

# %%
df = pd.get_dummies(
    df,
    columns=['race/ethnicity'],
    drop_first=True
)

# %%
df.head()
# Out:
#    gender parental level of education         lunch test preparation course  \
# 0  female           bachelor's degree      standard                    none
# 1  female                some college      standard               completed
# 2  female             master's degree      standard                    none
# 3    male          associate's degree  free/reduced                    none
# 4    male                some college      standard                    none
#
#    math score  reading score  writing score  gender_enc  lunch_enc  \
# 0          72             72             74           0          1
# 1          69             90             88           0          1
# 2          90             95             93           0          1
# 3          47             57             44           1          0
# 4          76             78             75           1          1
#
#    test_prep_enc  parent_edu_enc  race/ethnicity_group B  \
# ...

# %%
df_encoded = df.drop(
    columns=[
        'gender',
        'parental level of education',
        'lunch',
        'test preparation course'
    ]
)

df_encoded.head()
# Out:
#    math score  reading score  writing score  gender_enc  lunch_enc  \
# 0          72             72             74           0          1
# 1          69             90             88           0          1
# 2          90             95             93           0          1
# 3          47             57             44           1          0
# 4          76             78             75           1          1
#
#    test_prep_enc  parent_edu_enc  race/ethnicity_group B  \
# 0              1             4.0                    True
# 1              0             2.0                   False
# 2              1             5.0                    True
# 3              1             3.0                   False
# 4              1             2.0                   False
#
#    race/ethnicity_group C  race/ethnicity_group D  race/ethnicity_group E
# 0                   False                   False                   False
# ...
